# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#csv-Datei einlesen
#nrows=3600 --> zeigt 1h an
df = pd.read_csv('spannung_Teilnehmer.csv', delimiter=';', header=0)
                 #, nrows=3600)
#Tabelle ausgeben
df
# Out:
#         Spannung  Sekunde
# 0         227.87        5
# 1         242.51       10
# 2         238.61       15
# 3         233.33       20
# 4         242.77       25
# ...          ...      ...
# 241915    218.35  1209580
# 241916    239.45  1209585
# 241917    229.63  1209590
# 241918    223.69  1209595
# 241919    230.74  1209600
#
# [241920 rows x 2 columns]

# %%
df.plot.scatter(x="Sekunde",
                y="Spannung")
# Out:
# <AxesSubplot:xlabel='Sekunde', ylabel='Spannung'>

# %%
durchschnitt=df.mean()
durchschnitt
# Out:
# Spannung       232.05933
# Sekunde     604802.50000
# dtype: float64

# %%
import matplotlib.pyplot as plt
x=df["Sekunde"]
y=df["Spannung"]
plt.plot(x,y)
#plt.axis( [0,1209600,195,265])
plt.axhline(y=200, color='red')
plt.axhline(y=260, color='red')

#plt.rcParams['figure.figsize'] = [12,8]
#plt.rcParams['figure.dpi'] = 100

# %%
import matplotlib.pyplot as plt
x=df["Sekunde"]
y=df["Spannung"]
plt.plot(x,y)

plt.axhline(y=200, color='red')
plt.axhline(y=260, color='red')
plt.axis( [0,1209600,195,265])
# Out:
# (0.0, 1209600.0, 195.0, 265.0)
